# %%
import pandas as pd
from pycaret.regression import setup, compare_models, blend_models, finalize_model, plot_model, predict_model, add_metric, evaluate_model,tune_model
import random

VERSION = "merge_baseline_blend_id_v6"

# %%
def preprocess(df):
    
    df['year'] = df["timestamp"].dt.year
    df['month'] = df["timestamp"].dt.month
    
    return df

# %%
main_train_data = pd.read_csv("HW_train_main_data.csv", parse_dates=["timestamp"])
main_test_data = pd.read_csv("HW_test_main_data.csv", parse_dates=["timestamp"])

main_train_data = main_train_data.sort_values(by=["timestamp"])
main_test_data = main_test_data.sort_values(by=["timestamp"])

add_train_data = pd.read_csv("HW_train_additional_data.csv")
add_test_data = pd.read_csv("HW_test_additional_data.csv")

# %%
main_train_data = main_train_data.merge(add_train_data, on="id")
main_test_data = main_test_data.merge(add_test_data, on="id")

main_train_data = preprocess(main_train_data)
main_test_data = preprocess(main_test_data)

# %%
setup(data=main_train_data.drop(['id'], axis = 1),
          target="price",
          fold = 5)

best_models  = compare_models(sort = 'RMSE', n_select = 3)

blender = blend_models(estimator_list=best_models)

tuned_blender = tune_model(blender)

pred = predict_model(tuned_blender, data= main_test_data.drop(['id'], axis = 1))
# Out:
# <style type="text/css">
# #T_5bcd2_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5bcd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bcd2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5bcd2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bcd2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bcd2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5bcd2_row0_col1" class="data row0 col1" >5677</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bcd2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5bcd2_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bcd2_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5bcd2_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bcd2_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5bcd2_row3_col1" class="data row3 col1" >(29000, 32)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bcd2_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5bcd2_row4_col1" class="data row4 col1" >(29000, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bcd2_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5bcd2_row5_col1" class="data row5 col1" >(20300, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5bcd2_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5bcd2_row6_col1" class="data row6 col1" >(8700, 34)</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5bcd2_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5bcd2_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5bcd2_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_5bcd2_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5bcd2_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_5bcd2_row9_col1" class="data row9 col1" >71.7%</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5bcd2_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_5bcd2_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5bcd2_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_5bcd2_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5bcd2_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_5bcd2_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5bcd2_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_5bcd2_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5bcd2_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_5bcd2_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5bcd2_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_5bcd2_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5bcd2_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_5bcd2_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5bcd2_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_5bcd2_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5bcd2_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_5bcd2_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5bcd2_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_5bcd2_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5bcd2_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5bcd2_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_5bcd2_row20_col1" class="data row20 col1" >2450</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_2914b th {
#   text-align: left;
# }
# #T_2914b_row0_col0, #T_2914b_row0_col6, #T_2914b_row1_col0, #T_2914b_row1_col1, #T_2914b_row1_col2, #T_2914b_row1_col3, #T_2914b_row1_col4, #T_2914b_row1_col5, #T_2914b_row1_col6, #T_2914b_row2_col0, #T_2914b_row2_col1, #T_2914b_row2_col2, #T_2914b_row2_col3, #T_2914b_row2_col4, #T_2914b_row2_col5, #T_2914b_row2_col6, #T_2914b_row3_col0, #T_2914b_row3_col1, #T_2914b_row3_col2, #T_2914b_row3_col3, #T_2914b_row3_col4, #T_2914b_row3_col5, #T_2914b_row4_col0, #T_2914b_row4_col1, #T_2914b_row4_col2, #T_2914b_row4_col3, #T_2914b_row4_col4, #T_2914b_row4_col5, #T_2914b_row4_col6, #T_2914b_row5_col0, #T_2914b_row5_col1, #T_2914b_row5_col2, #T_2914b_row5_col3, #T_2914b_row5_col4, #T_2914b_row5_col5, #T_2914b_row5_col6, #T_2914b_row6_col0, #T_2914b_row6_col1, #T_2914b_row6_col2, #T_2914b_row6_col3, #T_2914b_row6_col4, #T_2914b_row6_col5, #T_2914b_row6_col6, #T_2914b_row7_col0, #T_2914b_row7_col1, #T_2914b_row7_col2, #T_2914b_row7_col3, #T_2914b_row7_col4, #T_2914b_row7_col5, #T_2914b_row7_col6, #T_2914b_row8_col0, #T_2914b_row8_col1, #T_2914b_row8_col2, #T_2914b_row8_col3, #T_2914b_row8_col4, #T_2914b_row8_col5, #T_2914b_row8_col6, #T_2914b_row9_col0, #T_2914b_row9_col1, #T_2914b_row9_col2, #T_2914b_row9_col3, #T_2914b_row9_col4, #T_2914b_row9_col5, #T_2914b_row9_col6, #T_2914b_row10_col0, #T_2914b_row10_col1, #T_2914b_row10_col2, #T_2914b_row10_col3, #T_2914b_row10_col4, #T_2914b_row10_col5, #T_2914b_row10_col6, #T_2914b_row11_col0, #T_2914b_row11_col1, #T_2914b_row11_col2, #T_2914b_row11_col3, #T_2914b_row11_col4, #T_2914b_row11_col5, #T_2914b_row11_col6, #T_2914b_row12_col0, #T_2914b_row12_col1, #T_2914b_row12_col2, #T_2914b_row12_col3, #T_2914b_row12_col4, #T_2914b_row12_col5, #T_2914b_row12_col6, #T_2914b_row13_col0, #T_2914b_row13_col1, #T_2914b_row13_col2, #T_2914b_row13_col3, #T_2914b_row13_col4, #T_2914b_row13_col5, #T_2914b_row13_col6, #T_2914b_row14_col0, #T_2914b_row14_col1, #T_2914b_row14_col2, #T_2914b_row14_col3, #T_2914b_row14_col4, #T_2914b_row14_col5, #T_2914b_row14_col6, #T_2914b_row15_col0, #T_2914b_row15_col1, #T_2914b_row15_col2, #T_2914b_row15_col3, #T_2914b_row15_col4, #T_2914b_row15_col5, #T_2914b_row15_col6, #T_2914b_row16_col0, #T_2914b_row16_col1, #T_2914b_row16_col2, #T_2914b_row16_col3, #T_2914b_row16_col4, #T_2914b_row16_col5, #T_2914b_row16_col6, #T_2914b_row17_col0, #T_2914b_row17_col1, #T_2914b_row17_col2, #T_2914b_row17_col3, #T_2914b_row17_col4, #T_2914b_row17_col5, #T_2914b_row17_col6, #T_2914b_row18_col0, #T_2914b_row18_col1, #T_2914b_row18_col2, #T_2914b_row18_col3, #T_2914b_row18_col4, #T_2914b_row18_col5, #T_2914b_row18_col6, #T_2914b_row19_col0, #T_2914b_row19_col1, #T_2914b_row19_col2, #T_2914b_row19_col3, #T_2914b_row19_col4, #T_2914b_row19_col5, #T_2914b_row19_col6 {
#   text-align: left;
# }
# #T_2914b_row0_col1, #T_2914b_row0_col2, #T_2914b_row0_col3, #T_2914b_row0_col4, #T_2914b_row0_col5, #T_2914b_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2914b_row0_col7, #T_2914b_row1_col7, #T_2914b_row2_col7, #T_2914b_row3_col7, #T_2914b_row4_col7, #T_2914b_row5_col7, #T_2914b_row6_col7, #T_2914b_row7_col7, #T_2914b_row8_col7, #T_2914b_row11_col7, #T_2914b_row12_col7, #T_2914b_row13_col7, #T_2914b_row14_col7, #T_2914b_row16_col7, #T_2914b_row17_col7, #T_2914b_row18_col7, #T_2914b_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2914b_row9_col7, #T_2914b_row10_col7, #T_2914b_row15_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2914b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2914b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2914b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2914b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2914b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2914b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2914b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2914b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2914b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2914b_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_2914b_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_2914b_row0_col1" class="data row0 col1" >1507859.9222</td>
#       <td id="T_2914b_row0_col2" class="data row0 col2" >7650444852485.9219</td>
#       <td id="T_2914b_row0_col3" class="data row0 col3" >2764875.6126</td>
#       <td id="T_2914b_row0_col4" class="data row0 col4" >0.7029</td>
#       <td id="T_2914b_row0_col5" class="data row0 col5" >0.4737</td>
#       <td id="T_2914b_row0_col6" class="data row0 col6" >0.4409</td>
#       <td id="T_2914b_row0_col7" class="data row0 col7" >1.0340</td>
#     </tr>
#     <tr>
#       <th id="T_2914b_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_2914b_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2914b_row1_col1" class="data row1 col1" >1564342.0319</td>
#       <td id="T_2914b_row1_col2" class="data row1 col2" >8417702538628.0645</td>
#       <td id="T_2914b_row1_col3" class="data row1 col3" >2898731.9599</td>
#       <td id="T_2914b_row1_col4" class="data row1 col4" >0.6742</td>
#       <td id="T_2914b_row1_col5" class="data row1 col5" >0.4783</td>
#       <td id="T_2914b_row1_col6" class="data row1 col6" >0.4503</td>
#       <td id="T_2914b_row1_col7" class="data row1 col7" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_2914b_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_2914b_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_2914b_row2_col1" class="data row2 col1" >1592522.9000</td>
#       <td id="T_2914b_row2_col2" class="data row2 col2" >8535209725132.7998</td>
#       <td id="T_2914b_row2_col3" class="data row2 col3" >2919996.8500</td>
#       <td id="T_2914b_row2_col4" class="data row2 col4" >0.6689</td>
#       <td id="T_2914b_row2_col5" class="data row2 col5" >0.4841</td>
#       <td id="T_2914b_row2_col6" class="data row2 col6" >0.4490</td>
#       <td id="T_2914b_row2_col7" class="data row2 col7" >0.3620</td>
#     </tr>
#     <tr>
#       <th id="T_2914b_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_2914b_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_2914b_row3_col1" class="data row3 col1" >1557001.7065</td>
#       <td id="T_2914b_row3_col2" class="data row3 col2" >8599206927008.3184</td>
#       <td id="T_2914b_row3_col3" class="data row3 col3" >2931297.5706</td>
#       <td id="T_2914b_row3_col4" class="data row3 col4" >0.6663</td>
#       <td id="T_2914b_row3_col5" class="data row3 col5" >0.4778</td>
#       <td id="T_2914b_row3_col6" class="data row3 col6" >0.4386</td>
#       <td id="T_2914b_row3_col7" class="data row3 col7" >0.6900</td>
#     </tr>
#     <tr>
#       <th id="T_2914b_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_2914b_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_2914b_row4_col1" class="data row4 col1" >1565905.3811</td>
#       <td id="T_2914b_row4_col2" class="data row4 col2" >8600808015980.1133</td>
#       <td id="T_2914b_row4_col3" class="data row4 col3" >2931468.9012</td>
#       <td id="T_2914b_row4_col4" class="data row4 col4" >0.6664</td>
#       <td id="T_2914b_row4_col5" class="data row4 col5" >0.4781</td>
#       <td id="T_2914b_row4_col6" class="data row4 col6" >0.4419</td>
#       <td id="T_2914b_row4_col7" class="data row4 col7" >1.2960</td>
#     </tr>
#     <tr>
#       <th id="T_2914b_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_2914b_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_2914b_row5_col1" class="data row5 col1" >1665829
# <style type="text/css">
# #T_5e0f4_row5_col0, #T_5e0f4_row5_col1, #T_5e0f4_row5_col2, #T_5e0f4_row5_col3, #T_5e0f4_row5_col4, #T_5e0f4_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_5e0f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e0f4_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_5e0f4_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_5e0f4_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_5e0f4_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_5e0f4_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_5e0f4_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e0f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e0f4_row0_col0" class="data row0 col0" >1551858.0968</td>
#       <td id="T_5e0f4_row0_col1" class="data row0 col1" >8779886089248.7441</td>
#       <td id="T_5e0f4_row0_col2" class="data row0 col2" >2963087.2564</td>
#       <td id="T_5e0f4_row0_col3" class="data row0 col3" >0.7039</td>
#       <td id="T_5e0f4_row0_col4" class="data row0 col4" >0.4885</td>
#       <td id="T_5e0f4_row0_col5" class="data row0 col5" >0.4751</td>
#     </tr>
#     <tr>
#       <th id="T_5e0f4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5e0f4_row1_col0" class="data row1 col0" >1485046.7397</td>
#       <td id="T_5e0f4_row1_col1" class="data row1 col1" >7614891840884.4541</td>
#       <td id="T_5e0f4_row1_col2" class="data row1 col2" >2759509.3479</td>
#       <td id="T_5e0f4_row1_col3" class="data row1 col3" >0.6986</td>
#       <td id="T_5e0f4_row1_col4" class="data row1 col4" >0.4578</td>
#       <td id="T_5e0f4_row1_col5" class="data row1 col5" >0.4125</td>
#     </tr>
#     <tr>
#       <th id="T_5e0f4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5e0f4_row2_col0" class="data row2 col0" >1526191.0416</td>
#       <td id="T_5e0f4_row2_col1" class="data row2 col1" >7181629647158.4854</td>
#       <td id="T_5e0f4_row2_col2" class="data row2 col2" >2679856.2736</td>
#       <td id="T_5e0f4_row2_col3" class="data row2 col3" >0.6893</td>
#       <td id="T_5e0f4_row2_col4" class="data row2 col4" >0.4877</td>
#       <td id="T_5e0f4_row2_col5" class="data row2 col5" >0.4623</td>
#     </tr>
#     <tr>
#       <th id="T_5e0f4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5e0f4_row3_col0" class="data row3 col0" >1505315.6660</td>
#       <td id="T_5e0f4_row3_col1" class="data row3 col1" >7592025279363.2783</td>
#       <td id="T_5e0f4_row3_col2" class="data row3 col2" >2755363.0032</td>
#       <td id="T_5e0f4_row3_col3" class="data row3 col3" >0.7137</td>
#       <td id="T_5e0f4_row3_col4" class="data row3 col4" >0.4680</td>
#       <td id="T_5e0f4_row3_col5" class="data row3 col5" >0.4285</td>
#     </tr>
#     <tr>
#       <th id="T_5e0f4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5e0f4_row4_col0" class="data row4 col0" >1500446.8994</td>
#       <td id="T_5e0f4_row4_col1" class="data row4 col1" >8068818796537.6240</td>
#       <td id="T_5e0f4_row4_col2" class="data row4 col2" >2840566.6330</td>
#       <td id="T_5e0f4_row4_col3" class="data row4 col3" >0.6734</td>
#       <td id="T_5e0f4_row4_col4" class="data row4 col4" >0.4693</td>
#       <td id="T_5e0f4_row4_col5" class="data row4 col5" >0.4286</td>
#     </tr>
#     <tr>
#       <th id="T_5e0f4_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_5e0f4_row5_col0" class="data row5 col0" >1513771.6887</td>
#       <td id="T_5e0f4_row5_col1" class="data row5 col1" >7847450330638.5166</td>
#       <td id="T_5e0f4_row5_col2" class="data row5 col2" >2799676.5028</td>
#       <td id="T_5e0f4_row5_col3" class="data row5 col3" >0.6958</td>
#       <td id="T_5e0f4_row5_col4" class="data row5 col4" >0.4743</td>
#       <td id="T_5e0f4_row5_col5" class="data row5 col5" >0.4414</td>
#     </tr>
#     <tr>
#       <th id="T_5e0f4_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_5e0f4_row6_col0" class="data row6 col0" >23147.3188</td>
#       <td id="T_5e0f4_row6_col1" class="data row6 col1" >544257849213.9584</td>
#       <td id="T_5e0f4_row6_col2" class="data row6 col2" >96238.2991</td>
#       <td id="T_5e0f4_row6_col3" class="data row6 col3" >0.0137</td>
#       <td id="T_5e0f4_row6_col4" class="data row6 col4" >0.0120</td>
#       <td id="T_5e0f4_row6_col5" class="data row6 col5" >0.0234</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   21:25:41
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .           Voting Regressor
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 5 folds for each of 10 candidates, totalling 50 fits

# %%
pred

# %%
pred['id'] = main_test_data["id"]
pred = pred.sort_values(by=["id"])
pred = pred.rename(columns={"prediction_label":"predicted_price"}).reset_index()
pred[['id', "predicted_price"]].to_csv(f'{VERSION}.csv', index=False)
